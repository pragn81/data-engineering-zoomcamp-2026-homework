# %%
from kafka import KafkaConsumer

server = 'localhost:9092'
topic_name = 'green-trips'

# %%
from models import Ride, ride_deserializer

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    group_id='rides-database',
    value_deserializer=ride_deserializer
)

# %%
#for record in consumer:
#    print(record.value)

# %%
import psycopg2

conn = psycopg2.connect(
    host='localhost',
    port=5432,
    database='postgres',
    user='postgres',
    password='postgres'
)

conn.autocommit = True
cur = conn.cursor()

# %%
from datetime import datetime

print(f"Listening to {topic_name} and writing to PostgreSQL...")

count = 0
for message in consumer:
    ride = message.value
    #pickup_dt = datetime.fromtimestamp(ride.lpep_pickup_datetime / 1000)
    #dropoff_dt = datetime.fromtimestamp(ride.lpep_dropoff_datetime / 1000)
    pickup_dt = ride.lpep_pickup_datetime
    dropoff_dt = ride.lpep_dropoff_datetime
    cur.execute(
        """INSERT INTO processed_events
           (pickup_datetime, dropoff_datetime, PULocationID, DOLocationID, passenger_count, trip_distance, tip_amount, total_amount)
           VALUES (%s, %s, %s, %s, %s, %s, %s, %s)""",
        (pickup_dt, dropoff_dt,
         ride.PULocationID, ride.DOLocationID, ride.passenger_count,
         ride.trip_distance, ride.tip_amount, ride.total_amount)
    )
    count += 1
    if count % 100 == 0:
        print(f"Inserted {count} rows...")

consumer.close()
cur.close()
conn.close()
# Out:
# Listening to green-trips and writing to PostgreSQL...
# Inserted 100 rows...
# Inserted 200 rows...
# Inserted 300 rows...
# Inserted 400 rows...
# Inserted 500 rows...
# Inserted 600 rows...
# Inserted 700 rows...
# Inserted 800 rows...
# Inserted 900 rows...
# Inserted 1000 rows...
# Inserted 1100 rows...
# Inserted 1200 rows...
# Inserted 1300 rows...
# Inserted 1400 rows...
# Inserted 1500 rows...
# Inserted 1600 rows...
# Inserted 1700 rows...
# Inserted 1800 rows...
# Inserted 1900 rows...
# Inserted 2000 rows...
# Inserted 2100 rows...
# Inserted 2200 rows...
# Inserted 2300 rows...
# Inserted 2400 rows...
# Inserted 2500 rows...
# Inserted 2600 rows...
# Inserted 2700 rows...
# Inserted 2800 rows...
# Inserted 2900 rows...
# Inserted 3000 rows...
# Inserted 3100 rows...
# Inserted 3200 rows...
# Inserted 3300 rows...
# Inserted 3400 rows...
# Inserted 3500 rows...
# Inserted 3600 rows...
# Inserted 3700 rows...
# Inserted 3800 rows...
# Inserted 3900 rows...
# Inserted 4000 rows...
# Inserted 4100 rows...
# Inserted 4200 rows...
# Inserted 4300 rows...
# Inserted 4400 rows...
# Inserted 4500 rows...
# Inserted 4600 rows...
# Inserted 4700 rows...
# Inserted 4800 rows...
# Inserted 4900 rows...
# Inserted 5000 rows...
# Inserted 5100 rows...
# Inserted 5200 rows...
# Inserted 5300 rows...
# Inserted 5400 rows...
# Inserted 5500 rows...
# Inserted 5600 rows...
# Inserted 5700 rows...
# Inserted 5800 rows...
# Inserted 5900 rows...
# Inserted 6000 rows...
# Inserted 6100 rows...
# Inserted 6200 rows...
# Inserted 6300 rows...
# Inserted 6400 rows...
# Inserted 6500 rows...
# Inserted 6600 rows...
# Inserted 6700 rows...
# Inserted 6800 rows...
# Inserted 6900 rows...
# Inserted 7000 rows...
# Inserted 7100 rows...
# Inserted 7200 rows...
# Inserted 7300 rows...
# Inserted 7400 rows...
# Inserted 7500 rows...
# Inserted 7600 rows...
# Inserted 7700 rows...
# Inserted 7800 rows...
# Inserted 7900 rows...
# Inserted 8000 rows...
# Inserted 8100 rows...
# Inserted 8200 rows...
# Inserted 8300 rows...
# Inserted 8400 rows...
# Inserted 8500 rows...
# Inserted 8600 rows...
# Inserted 8700 rows...
# Inserted 8800 rows...
# Inserted 8900 rows...
# Inserted 9000 rows...
# Inserted 9100 rows...
# Inserted 9200 rows...
# Inserted 9300 rows...
# Inserted 9400 rows...
# Inserted 9500 rows...
# Inserted 9600 rows...
# Inserted 9700 rows...
# Inserted 9800 rows...
# Inserted 9900 rows...
# Inserted 10000 rows...
# Inserted 10100 rows...
# Inserted 10200 rows...
# Inserted 10300 rows...
# Inserted 10400 rows...
# Inserted 10500 rows...
# Inserted 10600 rows...
# Inserted 10700 rows...
# Inserted 10800 rows...
# Inserted 10900 rows...
# Inserted 11000 rows...
# Inserted 11100 rows...
# Inserted 11200 rows...
# Inserted 11300 rows...
# Inserted 11400 rows...
# Inserted 11500 rows...
# Inserted 11600 rows...
# Inserted 11700 rows...
# Inserted 11800 rows...
# Inserted 11900 rows...
# Inserted 12000 rows...
# Inserted 12100 rows...
# Inserted 12200 rows...
# Inserted 12300 rows...
# Inserted 12400 rows...
# Inserted 12500 rows...
# Inserted 12600 rows...
# Inserted 12700 rows...
# Inserted 12800 rows...
# Inserted 12900 rows...
# Inserted 13000 rows...
# Inserted 13100 rows...
# Inserted 13200 rows...
# Inserted 13300 rows...
# Inserted 13400 rows...
# Inserted 13500 rows...
# Inserted 13600 rows...
# Inserted 13700 rows...
# Inserted 13800 rows...
# Inserted 13900 rows...
# Inserted 14000 rows...
# Inserted 14100 rows...
# Inserted 14200 rows...
# Inserted 14300 rows...
# Inserted 14400 rows...
# Inserted 14500 rows...
# Inserted 14600 rows...
# Inserted 14700 rows...
# Inserted 14800 rows...
# Inserted 14900 rows...
# Inserted 15000 rows...
# Inserted 15100 rows...
# Inserted 15200 rows...
# Inserted 15300 rows...
# Inserted 15400 rows...
# Inserted 15500 rows...
# Inserted 15600 rows...
# Inserted 15700 rows...
# Inserted 15800 rows...
# Inserted 15900 rows...
# Inserted 16000 rows...
# Inserted 16100 rows...
# Inserted 16200 rows...
# Inserted 16300 rows...
# Inserted 16400 rows...
# Inserted 16500 rows...
# Inserted 16600 rows...
# Inserted 16700 rows...
# Inserted 16800 rows...
# Inserted 16900 rows...
# Inserted 17000 rows...
# Inserted 17100 rows...
# Inserted 17200 rows...
# Inserted 17300 rows...
# Inserted 17400 rows...
# Inserted 17500 rows...
# Inserted 17600 rows...
# Inserted 17700 rows...
# Inserted 17800 rows...
# Inserted 17900 rows...
# Inserted 18000 rows...
# Inserted 18100 rows...
# Inserted 18200 rows...
# Inserted 18300 rows...
# Inserted 18400 rows...
# Inserted 18500 rows...
# Inserted 18600 rows...
# Inserted 18700 rows...
# Inserted 18800 rows...
# Inserted 18900 rows...
# Inserted 19000 rows...
# Inserted 19100 rows...
# Inserted 19200 rows...
# Inserted 19300 rows...
# Inserted 19400 rows...
# Inserted 19500 rows...
# Inserted 19600 rows...
# Inserted 19700 rows...
# Inserted 19800 rows...
# Inserted 19900 rows...
# Inserted 20000 rows...
# Inserted 20100 rows...
# Inserted 20200 rows...
# Inserted 20300 rows...
# Inserted 20400 rows...
# Inserted 20500 rows...
# Inserted 20600 rows...
# Inserted 20700 rows...
# Inserted 20800 rows...
# Inserted 20900 rows...
# Inserted 21000 rows...
# Inserted 21100 rows...
# Inserted 21200 rows...
# Inserted 21300 rows...
# Inserted 21400 rows...
# Inserted 21500 rows...
# Inserted 21600 rows...
# Inserted 21700 rows...
# Inserted 21800 rows...
# Inserted 21900 rows...
# Inserted 22000 rows...
# Inserted 22100 rows...
# Inserted 22200 rows...
# Inserted 22300 rows...
# Inserted 22400 rows...
# Inserted 22500 rows...
# Inserted 22600 rows...
# Inserted 22700 rows...
# Inserted 22800 rows...
# Inserted 22900 rows...
# Inserted 23000 rows...
# Inserted 23100 rows...
# Inserted 23200 rows...
# Inserted 23300 rows...
# Inserted 23400 rows...
# Inserted 23500 rows...
# Inserted 23600 rows...
# Inserted 23700 rows...
# Inserted 23800 rows...
# Inserted 23900 rows...
# Inserted 24000 rows...
# Inserted 24100 rows...
# Inserted 24200 rows...
# Inserted 24300 rows...
# Inserted 24400 rows...
# Inserted 24500 rows...
# Inserted 24600 rows...
# Inserted 24700 rows...
# Inserted 24800 rows...
# Inserted 24900 rows...
# Inserted 25000 rows...
# Inserted 25100 rows...
# Inserted 25200 rows...
# Inserted 25300 rows...
# Inserted 25400 rows...
# Inserted 25500 rows...
# Inserted 25600 rows...
# Inserted 25700 rows...
# Inserted 25800 rows...
# Inserted 25900 rows...
# Inserted 26000 rows...
# Inserted 26100 rows...
# Inserted 26200 rows...
# Inserted 26300 rows...
# Inserted 26400 rows...
# Inserted 26500 rows...
# Inserted 26600 rows...
# Inserted 26700 rows...
# Inserted 26800 rows...
# Inserted 26900 rows...
# Inserted 27000 rows...
# Inserted 27100 rows...
# Inserted 27200 rows...
# Inserted 27300 rows...
# Inserted 27400 rows...
# Inserted 27500 rows...
# Inserted 27600 rows...
# Inserted 27700 rows...
# Inserted 27800 rows...
# Inserted 27900 rows...
# Inserted 28000 rows...
# Inserted 28100 rows...
# Inserted 28200 rows...
# Inserted 28300 rows...
# Inserted 28400 rows...
# Inserted 28500 rows...
# Inserted 28600 rows...
# Inserted 28700 rows...
# Inserted 28800 rows...
# Inserted 28900 rows...
# Inserted 29000 rows...
# Inserted 29100 rows...
# Inserted 29200 rows...
# Inserted 29300 rows...
# Inserted 29400 rows...
# Inserted 29500 rows...
# Inserted 29600 rows...
# Inserted 29700 rows...
# Inserted 29800 rows...
# Inserted 29900 rows...
# Inserted 30000 rows...
# Inserted 30100 rows...
# Inserted 30200 rows...
# Inserted 30300 rows...
# Inserted 30400 rows...
# Inserted 30500 rows...
# Inserted 30600 rows...
# Inserted 30700 rows...
# Inserted 30800 rows...
# Inserted 30900 rows...
# Inserted 31000 rows...
# Inserted 31100 rows...
# Inserted 31200 rows...
# Inserted 31300 rows...
# Inserted 31400 rows...
# Inserted 31500 rows...
# Inserted 31600 rows...
# Inserted 31700 rows...
# Inserted 31800 rows...
# Inserted 31900 rows...
# Inserted 32000 rows...
# Inserted 32100 rows...
# Inserted 32200 rows...
# Inserted 32300 rows...
# Inserted 32400 rows...
# Inserted 32500 rows...
# Inserted 32600 rows...
# Inserted 32700 rows...
# Inserted 32800 rows...
# Inserted 32900 rows...
# Inserted 33000 rows...
# Inserted 33100 rows...
# Inserted 33200 rows...
# Inserted 33300 rows...
# Inserted 33400 rows...
# Inserted 33500 rows...
# Inserted 33600 rows...
# Inserted 33700 rows...
# Inserted 33800 rows...
# Inserted 33900 rows...
# Inserted 34000 rows...
# Inserted 34100 rows...
# Inserted 34200 rows...
# Inserted 34300 rows...
# Inserted 34400 rows...
# Inserted 34500 rows...
# Inserted 34600 rows...
# Inserted 34700 rows...
# Inserted 34800 rows...
# Inserted 34900 rows...
# Inserted 35000 rows...
# Inserted 35100 rows...
# Inserted 35200 rows...
# Inserted 35300 rows...
# Inserted 35400 rows...
# Inserted 35500 rows...
# Inserted 35600 rows...
# Inserted 35700 rows...
# Inserted 35800 rows...
# Inserted 35900 rows...
# Inserted 36000 rows...
# Inserted 36100 rows...
# Inserted 36200 rows...
# Inserted 36300 rows...
# Inserted 36400 rows...
# Inserted 36500 rows...
# Inserted 36600 rows...
# Inserted 36700 rows...
# Inserted 36800 rows...
# Inserted 36900 rows...
# Inserted 37000 rows...
# Inserted 37100 rows...
# Inserted 37200 rows...
# Inserted 37300 rows...
# Inserted 37400 rows...
# Inserted 37500 rows...
# Inserted 37600 rows...
# Inserted 37700 rows...
# Inserted 37800 rows...
# Inserted 37900 rows...
# Inserted 38000 rows...
# Inserted 38100 rows...
# Inserted 38200 rows...
# Inserted 38300 rows...
# Inserted 38400 rows...
# Inserted 38500 rows...
# Inserted 38600 rows...
# Inserted 38700 rows...
# Inserted 38800 rows...
# Inserted 38900 rows...
# Inserted 39000 rows...
# Inserted 39100 rows...
# Inserted 39200 rows...
# Inserted 39300 rows...
# Inserted 39400 rows...
# Inserted 39500 rows...
# Inserted 39600 rows...
# Inserted 39700 rows...
# Inserted 39800 rows...
# Inserted 39900 rows...
# Inserted 40000 rows...
# Inserted 40100 rows...
# Inserted 40200 rows...
# Inserted 40300 rows...
# Inserted 40400 rows...
# Inserted 40500 rows...
# Inserted 40600 rows...
# Inserted 40700 rows...
# Inserted 40800 rows...
# Inserted 40900 rows...
# Inserted 41000 rows...
# Inserted 41100 rows...
# Inserted 41200 rows...
# Inserted 41300 rows...
# Inserted 41400 rows...
# Inserted 41500 rows...
# Inserted 41600 rows...
# Inserted 41700 rows...
# Inserted 41800 rows...
# Inserted 41900 rows...
# Inserted 42000 rows...
# Inserted 42100 rows...
# Inserted 42200 rows...
# Inserted 42300 rows...
# Inserted 42400 rows...
# Inserted 42500 rows...
# Inserted 42600 rows...
# Inserted 42700 rows...
# Inserted 42800 rows...
# Inserted 42900 rows...
# Inserted 43000 rows...
# Inserted 43100 rows...
# Inserted 43200 rows...
# Inserted 43300 rows...
# Inserted 43400 rows...
# Inserted 43500 rows...
# Inserted 43600 rows...
# Inserted 43700 rows...
# Inserted 43800 rows...
# Inserted 43900 rows...
# Inserted 44000 rows...
# Inserted 44100 rows...
# Inserted 44200 rows...
# Inserted 44300 rows...
# Inserted 44400 rows...
# Inserted 44500 rows...
# Inserted 44600 rows...
# Inserted 44700 rows...
# Inserted 44800 rows...
# Inserted 44900 rows...
# Inserted 45000 rows...
# Inserted 45100 rows...
# Inserted 45200 rows...
# Inserted 45300 rows...
# Inserted 45400 rows...
# Inserted 45500 rows...
# Inserted 45600 rows...
# Inserted 45700 rows...
# Inserted 45800 rows...
# Inserted 45900 rows...
# Inserted 46000 rows...
# Inserted 46100 rows...
# Inserted 46200 rows...
# Inserted 46300 rows...
# Inserted 46400 rows...
# Inserted 46500 rows...
# Inserted 46600 rows...
# Inserted 46700 rows...
# Inserted 46800 rows...
# Inserted 46900 rows...
# Inserted 47000 rows...
# Inserted 47100 rows...
# Inserted 47200 rows...
# Inserted 47300 rows...
# Inserted 47400 rows...
# Inserted 47500 rows...
# Inserted 47600 rows...
# Inserted 47700 rows...
# Inserted 47800 rows...
# Inserted 47900 rows...
# Inserted 48000 rows...
# Inserted 48100 rows...
# Inserted 48200 rows...
# Inserted 48300 rows...
# Inserted 48400 rows...
# Inserted 48500 rows...
# Inserted 48600 rows...
# Inserted 48700 rows...
# Inserted 48800 rows...
# Inserted 48900 rows...
# Inserted 49000 rows...
# Inserted 49100 rows...
# Inserted 49200 rows...
# Inserted 49300 rows...
# Inserted 49400 rows...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 6
#       3 print(f"Listening to {topic_name} and writing to PostgreSQL...")
#       5 count = 0
# ----> 6 for message in consumer:
#       7     ride = message.value
#       8     #pickup_dt = datetime.fromtimestamp(ride.lpep_pickup_datetime / 1000)
#       9     #dropoff_dt = datetime.fromtimestamp(ride.lpep_dropoff_datetime / 1000)
#
# File /workspaces/data-engineering-zoomcamp-2026-homework/07-streaming/workshop/.venv/lib/python3.13/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File /workspaces/data-engineering-zoomcamp-2026-homework/07-streaming/workshop/.venv/lib/python3.13/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File /workspaces/data-engineering-zoomcamp-2026-homework/07-streaming/workshop/.venv/lib/python3.13/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File /workspaces/data-engineering-zoomcamp-2026-homework/07-streaming/workshop/.venv/lib/python3.13/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File /workspaces/data-engineering-zoomcamp-2026-homework/07-streaming/workshop/.venv/lib/python3.13/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File /workspaces/data-engineering-zoomcamp-2026-homework/07-streaming/workshop/.venv/lib/python3.13/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File ~/.local/share/uv/python/cpython-3.13.12-linux-x86_64-gnu/lib/python3.13/selectors.py:452, in EpollSelector.select(self, timeout)
#     450 ready = []
#     451 try:
# --> 452     fd_event_list = self._selector.poll(timeout, max_ev)
#     453 except InterruptedError:
#     454     return ready
#
# KeyboardInterrupt:
